# %%
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
arquivo = 'politicos_outubro.csv'

# %%
df = pd.read_csv(arquivo)

# %%
df.reset_index().head()
# Out:
#    index  Unnamed: 0  angry  comments                 date  \
# 0      0           0      0        18  2017-09-30 17:07:35
# 1      1           1      4       403  2017-09-30 18:43:31
# 2      2           2     13       114  2017-09-30 20:07:47
# 3      3           3      0         3  2017-10-01 18:00:01
# 4      4           4      0         2  2017-10-01 13:48:25
#
#                         facebook_id  \
# 0  199599520097304_1654815461242362
# 1  604028822974212_1593303257380092
# 2  194263324017292_1321893141254299
# 3  191644047572141_1419668881436312
# 4  223382044339765_1717379798273308
#
#                                              fb_link  haha  like link  love  \
# 0  https://www.facebook.com/ad.alvarodias/posts/1...     1   137  NaN     6
# 1  https://www.facebook.com/magnomalta/posts/1593...    32  6023  NaN   230
# 2  https://www.facebook.com/RodrigoMaiaRJ/videos/...     0   166  NaN     5
# 3  https://www.facebook.com/rafaelgreca/posts/141...     0    22  NaN     3
# ...

# %%
agrupamento = df.groupby('nome')['shares'].mean()

# %%
agrupamento.plot.bar().get_figure()
